# %% [markdown]
# # **Algoritma *K-Means***

# %% [markdown]
# ## **Pengertian *K-Means Clustering***
#
# *K-Means Clustering*  adalah teknik pengelompokan data yang memisahkan data ke dalam cluster, mengelompokkan data dengan fitur yang sama bersama-sama dan mengelompokkan data dengan karakteristik yang berbeda ke dalam kelompok yang berbeda dengan centroid sebagai acuannya. Metode k-means membagi data menjadi beberapa kelompok sehingga data dengan karakteristik yang sama berada pada cluster yang sama dan data dengan karakteristik yang berbeda berada pada cluster yang berbeda
#
#
# ## **Manfaat *Clustering***
#
#
# - Clustering merupakan metode segmentasi data yang sangat berguna dalam prediksi dan analisa masalah bisnis tertentu. Misalnya Segmentasi pasar, marketing dan pemetaan zonasi wilayah.
# - Identifikasi obyek dalam bidang berbagai bidang seperti computer vision dan image processing.
#
# Hasil clustering yang baik akan menghasilkan tingkat kesamaan yang tinggi dalam satu kelas dan tingkat kesamaan yang rendah antar kelas. Kesamaan yang dimaksud merupakan pengukuran secaranumeric terhadap dua buah objek. Nilai kesamaan antar kedua objek akan semakin tinggi jika kedua objek yang dibandingkan memiliki kemiripan yang tinggi. Begitu juga dengan sebaliknya. Kualitas hasil clustering sangat bergantung pada metode yang dipakai

# %% [markdown]
# ## **Inertia (Sum Square error/SSE)**
#
#
# Dalam konteks algoritma *K-Means Clustering*, *inertia* (Sum Square error/SSE) adalah salah satu metrik evaluasi untuk menilai seberapa baik data dikelompokkan ke dalam klaster serta mengukur jumlah total jarak kuadrat antara setiap titik data dan pusat klaster (centroid) tempat titik tersebut.
#
# Inertia didefinisikan sebagai:
#
# $$
# \text{Inertia} = \sum_{i=1}^{n} \left\| x_i - \mu_{c_i} \right\|^2
# $$
#
# **Penjelasan Notasi**
# - $x_i$: Titik data ke-$i$
# - $\mu_{c_i}$: Centroid dari klaster tempat $x_i$ berada
# - $\left\| x_i - \mu_{c_i} \right\|^2$: Jarak Euclidean kuadrat antara $x_i$ dan centroid-nya
# - $n$: Jumlah total data

# %% [markdown]
# ## **Silhouette Analysis**
#
#
# Silhouette Analysis adalah metrik evaluasi lain yang lebih baik dari inertia dalam banyak kasus untuk mengevaluasi hasil clustering, seperti pada K-Means, karena mempertimbangkan dua hal sekaligus yaitu:
#
# - Kepadatan dalam klaster
#
# - Jarak antar klaster
#
# Silhouette Analysis mengukur seberapa mirip suatu titik data dengan klasternya sendiri dibandingkan dengan klaster terdekat lainnya. Rumusnya adalah:
#
# $$
# s(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Penjelasan Notasi**:
# - $a(i)$: Rata-rata jarak dari titik $i$ ke semua titik lain dalam klaster yang sama (cohesion)
# - $b(i)$: Rata-rata jarak dari titik $i$ ke semua titik dalam klaster terdekat yang bukan miliknya (separation)
# - $s(i)$: Skor silhouette untuk titik $i$, dengan nilai antara -1 dan 1
#
# Nilai skor $s(i)$ ditafsirkan sebagai berikut:
# - Jika $s(i) \approx 1$, maka titik berada jauh dari klaster lain dan cocok dengan klasternya
# - Jika $s(i) \approx 0$, maka titik berada di antara dua klaster
# - Jika $s(i) \approx -1$, maka titik bisa jadi salah masuk klaster
#
# Untuk mengevaluasi seluruh hasil clustering, digunakan rata-rata dari semua $s(i)$:
#
# $$
# S = \frac{1}{n} \sum_{i=1}^{n} s(i)
# $$
#
# - $n$: Jumlah total data
# - $S$: Silhouette score rata-rata seluruh data

# %% [markdown]
# ## **Implementasi dengan menggunakan data Iris**

# %%
# %pip install pymysql
# %pip install psycopg2
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.11/dist-packages (2.9.10)

# %% [markdown]
# ## **Library yang digunakan**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import silhouette_score
import psycopg2
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## **Pengumpulan Data**

# %%
def get_pg_data():
    conn = psycopg2.connect(
        host="pg-289a0f88-pendataa.g.aivencloud.com",
        user="avnadmin",
        password="AVNS_1tT_bnHq81keqZ9n-wh",
        database="defaultdb",
        port=22825
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM iris_postgresql")
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]
    cursor.close()
    conn.close()
    return pd.DataFrame(data, columns=columns)

def get_mysql_data():
    conn = pymysql.connect(
        host="mysql-9b686fb-pendataa.g.aivencloud.com",
        user="avnadmin",
        password="AVNS_ZuFdVS1OQkmHx4P1Wtp",
        database="defaultdb",
        port=22825
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM irismysql")
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]
    cursor.close()
    conn.close()
    return pd.DataFrame(data, columns=columns)

# Ambil data dari kedua database
df_postgresql = get_pg_data()
df_mysql = get_mysql_data()

# Gabungkan berdasarkan kolom 'id' dan 'Class'
df_merged = pd.merge(df_mysql, df_postgresql, on=["id", "class"], how="inner")

# Cetak semua data hasil gabungan tanpa indeks
print(df_merged.to_string(index=False))
# Out:
#  id           class  petal_length  petal_width  sepal_length  sepal_width
#   1     Iris-setosa          14.0          2.0          50.1         30.5
#   2     Iris-setosa          14.0          2.0          40.9         30.0
#   3     Iris-setosa          13.0          2.0          40.7         30.2
#   4     Iris-setosa          15.0          2.0          40.6         30.1
#   5     Iris-setosa          14.0          2.0          50.0         30.6
#   6     Iris-setosa           1.7          0.4           5.4          3.9
#   7     Iris-setosa           1.4          0.3           4.6          3.4
#   8     Iris-setosa           1.5          0.2           5.0          3.4
#   9     Iris-setosa           1.4          0.2           4.4          2.9
#  10     Iris-setosa           1.5          0.1           4.9          3.1
#  11     Iris-setosa           1.5          0.2           5.4          3.7
#  12     Iris-setosa           1.6          0.2           4.8          3.4
#  13     Iris-setosa           1.4          0.1           4.8          3.0
#  14     Iris-setosa           1.1          0.1           4.3          3.0
#  15     Iris-setosa           1.2          0.2           5.8          4.0
#  16     Iris-setosa           1.5          0.4           5.7          4.4
#  17     Iris-setosa           1.3          0.4           5.4          3.9
#  18     Iris-setosa           1.4          0.3           5.1          3.5
#  19     Iris-setosa           1.7          0.3           5.7          3.8
#  20     Iris-setosa           1.5          0.3           5.1          3.8
#  21     Iris-setosa           1.7          0.2           5.4          3.4
#  22     Iris-setosa           1.5          0.4           5.1          3.7
#  23     Iris-setosa           1.0          0.2           4.6          3.6
#  24     Iris-setosa           1.7          0.5           5.1          3.3
#  25     Iris-setosa           1.9          0.2           4.8          3.4
#  26     Iris-setosa           1.6          0.2           5.0          3.0
#  27     Iris-setosa           1.6          0.4           5.0          3.4
#  28     Iris-setosa           1.5          0.2           5.2          3.5
#  29     Iris-setosa           1.4          0.2           5.2          3.4
#  30     Iris-setosa           1.6          0.2           4.7          3.2
#  31     Iris-setosa           1.6          0.2           4.8          3.1
#  32     Iris-setosa           1.5          0.4           5.4          3.4
#  33     Iris-setosa           1.5          0.1           5.2          4.1
#  34     Iris-setosa           1.4          0.2           5.5          4.2
#  35     Iris-setosa           1.5          0.1           4.9          3.1
#  36     Iris-setosa           1.2          0.2           5.0          3.2
#  37     Iris-setosa           1.3          0.2           5.5          3.5
#  38     Iris-setosa           1.5          0.1           4.9          3.1
#  39     Iris-setosa           1.3          0.2           4.4          3.0
#  40     Iris-setosa           1.5          0.2           5.1          3.4
#  41     Iris-setosa           1.3          0.3           5.0          3.5
#  42     Iris-setosa           1.3          0.3           4.5          2.3
#  43     Iris-setosa           1.3          0.2           4.4          3.2
#  44     Iris-setosa           1.6          0.6           5.0          3.5
#  45     Iris-setosa           1.9          0.4           5.1          3.8
#  46     Iris-setosa           1.4          0.3           4.8          3.0
#  47     Iris-setosa           1.6          0.2           5.1          3.8
#  48     Iris-setosa           1.4          0.2           4.6          3.2
#  49     Iris-setosa           1.5          0.2           5.3          3.7
#  50     Iris-setosa           1.4          0.2           5.0          3.3
#  51 Iris-versicolor          40.7         14.0          70.0         30.2
#  52 Iris-versicolor          40.5         15.0          60.4         30.2
#  53 Iris-versicolor          40.9         15.0          60.9         30.1
#  54 Iris-versicolor          40.0         13.0          50.5         20.3
#  55 Iris-versicolor          40.6         15.0          60.5         20.8
#  56 Iris-versicolor           4.5          1.3           5.7          2.8
#  57 Iris-versicolor           4.7          1.6           6.3          3.3
#  58 Iris-versicolor           3.3          1.0           4.9          2.4
#  59 Iris-versicolor           4.6          1.3           6.6          2.9
#  60 Iris-versicolor           3.9          1.4           5.2          2.7
#  61 Iris-versicolor           3.5          1.0           5.0          2.0
#  62 Iris-versicolor           4.2          1.5           5.9          3.0
#  63 Iris-versicolor           4.0          1.0           6.0          2.2
#  64 Iris-versicolor           4.7          1.4           6.1          2.9
#  65 Iris-versicolor           3.6          1.3           5.6          2.9
#  66 Iris-versicolor           4.4          1.4           6.7          3.1
#  67 Iris-versicolor           4.5          1.5           5.6          3.0
#  68 Iris-versicolor           4.1          1.0           5.8          2.7
#  69 Iris-versicolor           4.5          1.5           6.2          2.2
#  70 Iris-versicolor           3.9          1.1           5.6          2.5
#  71 Iris-versicolor           4.8          1.8           5.9          3.2
#  72 Iris-versicolor           4.0          1.3           6.1          2.8
#  73 Iris-versicolor           4.9          1.5           6.3          2.5
#  74 Iris-versicolor           4.7          1.2           6.1          2.8
#  75 Iris-versicolor           4.3          1.3           6.4          2.9
#  76 Iris-versicolor           4.4          1.4           6.6          3.0
#  77 Iris-versicolor           4.8          1.4           6.8          2.8
#  78 Iris-versicolor           5.0          1.7           6.7          3.0
#  79 Iris-versicolor           4.5          1.5           6.0          2.9
#  80 Iris-versicolor           3.5          1.0           5.7          2.6
#  81 Iris-versicolor           3.8          1.1           5.5          2.4
#  82 Iris-versicolor           3.7          1.0           5.5          2.4
#  83 Iris-versicolor           3.9          1.2           5.8          2.7
#  84 Iris-versicolor           5.1          1.6           6.0          2.7
#  85 Iris-versicolor           4.5          1.5           5.4          3.0
#  86 Iris-versicolor           4.5          1.6           6.0          3.4
#  87 Iris-versicolor           4.7          1.5           6.7          3.1
#  88 Iris-versicolor           4.4          1.3           6.3          2.3
#  89 Iris-versicolor           4.1          1.3           5.6          3.0
#  90 Iris-versicolor           4.0          1.3           5.5          2.5
#  91 Iris-versicolor           4.4          1.2           5.5          2.6
#  92 Iris-versicolor           4.6          1.4           6.1          3.0
#  93 Iris-versicolor           4.0          1.2           5.8          2.6
#  94 Iris-versicolor           3.3          1.0           5.0          2.3
#  95 Iris-versicolor           4.2          1.3           5.6          2.7
#  96 Iris-versicolor           4.2          1.2           5.7          3.0
#  97 Iris-versicolor           4.2          1.3           5.7          2.9
#  98 Iris-versicolor           4.3          1.3           6.2          2.9
#  99 Iris-versicolor           3.0          1.1           5.1          2.5
# 100 Iris-versicolor           4.1          1.3           5.7          2.8
# 101  Iris-virginica          60.0         20.5          60.3         30.3
# 102  Iris-virginica          50.1         19.0          50.8         20.7
# 103  Iris-virginica          50.9         20.1          70.1         30.0
# 104  Iris-virginica          50.6         18.0          60.3         20.9
# 105  Iris-virginica          50.8         20.2          60.5         30.0
# 106  Iris-virginica           6.6          2.1           7.6          3.0
# 107  Iris-virginica           4.5          1.7           4.9          2.5
# 108  Iris-virginica           6.3          1.8           7.3          2.9
# 109  Iris-virginica           5.8          1.8           6.7          2.5
# 110  Iris-virginica           6.1          2.5           7.2          3.6
# 111  Iris-virginica           5.1          2.0           6.5          3.2
# 112  Iris-virginica           5.3          1.9           6.4          2.7
# 113  Iris-virginica           5.5          2.1           6.8          3.0
# 114  Iris-virginica           5.0          2.0           5.7          2.5
# 115  Iris-virginica           5.1          2.4           5.8          2.8
# 116  Iris-virginica           5.3          2.3           6.4          3.2
# 117  Iris-virginica           5.5          1.8           6.5          3.0
# 118  Iris-virginica           6.7          2.2           7.7          3.8
# 119  Iris-virginica           6.9          2.3           7.7          2.6
# 120  Iris-virginica           5.0          1.5           6.0          2.2
# 121  Iris-virginica           5.7          2.3           6.9          3.2
# 122  Iris-virginica           4.9          2.0           5.6          2.8
# 123  Iris-virginica           6.7          2.0           7.7          2.8
# 124  Iris-virginica           4.9          1.8           6.3          2.7
# 125  Iris-virginica           5.7          2.1           6.7          3.3
# 126  Iris-virginica           6.0          1.8           7.2          3.2
# 127  Iris-virginica           4.8          1.8           6.2          2.8
# 128  Iris-virginica           4.9          1.8           6.1          3.0
# 129  Iris-virginica           5.6          2.1           6.4          2.8
# 130  Iris-virginica           5.8          1.6           7.2          3.0
# 131  Iris-virginica           6.1          1.9           7.4          2.8
# 132  Iris-virginica           6.4          2.0           7.9          3.8
# 133  Iris-virginica           5.6          2.2           6.4          2.8
# 134  Iris-virginica           5.1          1.5           6.3          2.8
# 135  Iris-virginica           5.6          1.4           6.1          2.6
# 136  Iris-virginica           6.1          2.3           7.7          3.0
# 137  Iris-virginica           5.6          2.4           6.3          3.4
# 138  Iris-virginica           5.5          1.8           6.4          3.1
# 139  Iris-virginica           4.8          1.8           6.0          3.0
# 140  Iris-virginica           5.4          2.1           6.9          3.1
# 141  Iris-virginica           5.6          2.4           6.7          3.1
# 142  Iris-virginica           5.1          2.3           6.9          3.1
# 143  Iris-virginica           5.1          1.9           5.8          2.7
# 144  Iris-virginica           5.9          2.3           6.8          3.2
# 145  Iris-virginica           5.7          2.5           6.7          3.3
# 146  Iris-virginica           5.2          2.3           6.7          3.0
# 147  Iris-virginica           5.0          1.9           6.3          2.5
# 148  Iris-virginica           5.2          2.0           6.5          3.0
# 149  Iris-virginica           5.4          2.3           6.2          3.4
# 150  Iris-virginica           5.1          1.8           5.9          3.0

# %% [markdown]
# ## **Clustering pada data Iris menggunakan K-Means dengan jumlah cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi clustering
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_
    accuracy = adjusted_rand_score(y, labels)

    print(f"\nHasil K-Means dengan {k} Klaster:")
    print(f"Centroids:\n{centroids}")
    print(f"Akurasi (Adjusted Rand Score): {accuracy:.3f}")

    return labels, centroids, accuracy

# 4. Jalankan clustering
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)
# Out:
# Hasil K-Means dengan 2 Klaster:
# Centroids:
# [[-0.2349652  -0.19808718 -0.25711389 -0.25878331]
#  [ 3.28951274  2.77322056  3.59959446  3.62296633]]
# Akurasi (Adjusted Rand Score): 0.003
#
# Hasil K-Means dengan 3 Klaster:
# Centroids:
# [[-0.32632653 -0.32750871 -0.2904267  -0.26588017]
#  [ 3.28951274  2.77322056  3.59959446  3.62296633]
#  [ 2.23179089  3.29629394  0.64233207 -0.067168  ]]
# Akurasi (Adjusted Rand Score): 0.002
#
# Hasil K-Means dengan 4 Klaster:
# Centroids:
# [[-0.32632653 -0.32750871 -0.2904267  -0.26588017]
#  [ 3.28752578  2.77721349  4.14265371  4.25851683]
#  [ 2.23179089  3.29629394  0.64233207 -0.067168  ]
#  [ 3.29149969  2.76922764  3.0565352   2.98741582]]
# Akurasi (Adjusted Rand Score): 0.005

# %% [markdown]
# ## **Model Plotting dengan Jumlah Cluster 2, 3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk melakukan K-Means, plotting dan menampilkan centroid
def perform_kmeans_plot(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    # Centroid dari masing-masing klaster
    centroids = kmeans.cluster_centers_

    # Plotting data dan centroid
    plt.figure(figsize=(8, 6))

    # Scatter plot untuk 2 fitur pertama (sepal length & sepal width)
    plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='Set1', marker='o', edgecolors='k', s=100)

    # Plot centroid dengan warna berbeda
    plt.scatter(centroids[:, 0], centroids[:, 1], c='black', marker='X', s=200, label='Centroids')

    plt.title(f"K-Means Clustering with {k} Clusters")
    plt.xlabel(feature_names[0])
    plt.ylabel(feature_names[1])
    plt.legend()
    plt.show()

# 4. Melakukan clustering dengan K=2, K=3, dan K=4 dan plot hasilnya
for k in [2, 3, 4]:
    perform_kmeans_plot(X_scaled, k)

# %% [markdown]
# ## **Menghitung Inertia untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk menghitung inertia secara manual
def calculate_inertia_step_by_step(X_scaled, labels, centroids):
    inertia = 0
    print("Langkah-langkah perhitungan Inertia:")

    for i in range(len(X_scaled)):
        cluster = labels[i]
        distance = np.linalg.norm(X_scaled[i] - centroids[cluster]) ** 2
        inertia += distance
        print(f"Titik data {i+1} (Fitur: {X_scaled[i]}), Klaster: {cluster}, "
              f"Centroid: {centroids[cluster]}, Jarak kuadrat: {distance:.3f}, "
              f"Inertia sementara: {inertia:.3f}")

    return inertia

# 4. Fungsi untuk menjalankan KMeans dan menghitung inertia manual
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_

    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids (fitur hasil standarisasi):\n{centroids}")

    # Hitung inertia manual
    manual_inertia = calculate_inertia_step_by_step(X_scaled, labels, centroids)
    print(f"\nTotal Inertia Manual: {manual_inertia:.3f}")

    # Bandingkan dengan inertia dari sklearn
    sklearn_inertia = kmeans.inertia_
    print(f"Inertia dari sklearn: {sklearn_inertia:.3f}")
    print("="*50)

    return labels, centroids, manual_inertia

# 5. Jalankan untuk k=2, 3, dan 4
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[-0.2349652  -0.19808718 -0.25711389 -0.25878331]
#  [ 3.28951274  2.77322056  3.59959446  3.62296633]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [ 2.60533824  3.3255754   0.64233207 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 21.329, Inertia sementara: 21.329
# Titik data 2 (Fitur: [ 1.99600568  3.25902662  0.64233207 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 17.775, Inertia sementara: 39.104
# Titik data 3 (Fitur: [ 1.98275932  3.28564613  0.55136737 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 17.745, Inertia sementara: 56.849
# Titik data 4 (Fitur: [ 1.97613614  3.27233638  0.73329677 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 17.950, Inertia sementara: 74.799
# Titik data 5 (Fitur: [ 2.59871506  3.33888515  0.64233207 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 21.386, Inertia sementara: 96.185
# Titik data 6 (Fitur: [-0.35522322 -0.21481945 -0.47653374 -0.46130785]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.104, Inertia sementara: 96.289
# Titik data 7 (Fitur: [-0.40820866 -0.28136822 -0.50382315 -0.48594159]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.149, Inertia sementara: 96.438
# Titik data 8 (Fitur: [-0.38171594 -0.28136822 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.148, Inertia sementara: 96.587
# Titik data 9 (Fitur: [-0.42145502 -0.347917   -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.181, Inertia sementara: 96.768
# Titik data 10 (Fitur: [-0.38833912 -0.32129749 -0.49472668 -0.53520907]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.172, Inertia sementara: 96.940
# Titik data 11 (Fitur: [-0.35522322 -0.24143896 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.136, Inertia sementara: 97.076
# Titik data 12 (Fitur: [-0.3949623  -0.28136822 -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.148, Inertia sementara: 97.224
# Titik data 13 (Fitur: [-0.3949623  -0.33460724 -0.50382315 -0.53520907]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.182, Inertia sementara: 97.406
# Titik data 14 (Fitur: [-0.4280782  -0.33460724 -0.53111256 -0.53520907]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.207, Inertia sementara: 97.613
# Titik data 15 (Fitur: [-0.3287305  -0.20150969 -0.52201609 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.142, Inertia sementara: 97.755
# Titik data 16 (Fitur: [-0.33535368 -0.14827067 -0.49472668 -0.46130785]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.110, Inertia sementara: 97.865
# Titik data 17 (Fitur: [-0.35522322 -0.21481945 -0.51291962 -0.46130785]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.121, Inertia sementara: 97.987
# Titik data 18 (Fitur: [-0.37509276 -0.26805847 -0.50382315 -0.48594159]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.137, Inertia sementara: 98.124
# Titik data 19 (Fitur: [-0.33535368 -0.2281292  -0.47653374 -0.48594159]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.111, Inertia sementara: 98.234
# Titik data 20 (Fitur: [-0.37509276 -0.2281292  -0.49472668 -0.48594159]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.129, Inertia sementara: 98.363
# Titik data 21 (Fitur: [-0.35522322 -0.28136822 -0.47653374 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.133, Inertia sementara: 98.496
# Titik data 22 (Fitur: [-0.37509276 -0.24143896 -0.49472668 -0.46130785]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.119, Inertia sementara: 98.615
# Titik data 23 (Fitur: [-0.40820866 -0.25474871 -0.54020903 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.177, Inertia sementara: 98.792
# Titik data 24 (Fitur: [-0.37509276 -0.29467798 -0.47653374 -0.43667411]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.109, Inertia sementara: 98.900
# Titik data 25 (Fitur: [-0.3949623  -0.28136822 -0.4583408  -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.136, Inertia sementara: 99.037
# Titik data 26 (Fitur: [-0.38171594 -0.33460724 -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.156, Inertia sementara: 99.193
# Titik data 27 (Fitur: [-0.38171594 -0.28136822 -0.48563021 -0.46130785]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.122, Inertia sementara: 99.314
# Titik data 28 (Fitur: [-0.36846958 -0.26805847 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.143, Inertia sementara: 99.457
# Titik data 29 (Fitur: [-0.36846958 -0.28136822 -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.149, Inertia sementara: 99.606
# Titik data 30 (Fitur: [-0.40158548 -0.30798773 -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.155, Inertia sementara: 99.761
# Titik data 31 (Fitur: [-0.3949623  -0.32129749 -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.156, Inertia sementara: 99.918
# Titik data 32 (Fitur: [-0.35522322 -0.28136822 -0.49472668 -0.46130785]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.119, Inertia sementara: 100.037
# Titik data 33 (Fitur: [-0.36846958 -0.18819994 -0.49472668 -0.53520907]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.151, Inertia sementara: 100.187
# Titik data 34 (Fitur: [-0.34860004 -0.17489018 -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.138, Inertia sementara: 100.325
# Titik data 35 (Fitur: [-0.38833912 -0.32129749 -0.49472668 -0.53520907]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.172, Inertia sementara: 100.497
# Titik data 36 (Fitur: [-0.38171594 -0.30798773 -0.52201609 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.167, Inertia sementara: 100.664
# Titik data 37 (Fitur: [-0.34860004 -0.26805847 -0.51291962 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.147, Inertia sementara: 100.811
# Titik data 38 (Fitur: [-0.38833912 -0.32129749 -0.49472668 -0.53520907]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.172, Inertia sementara: 100.982
# Titik data 39 (Fitur: [-0.42145502 -0.33460724 -0.51291962 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.182, Inertia sementara: 101.164
# Titik data 40 (Fitur: [-0.37509276 -0.28136822 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.146, Inertia sementara: 101.311
# Titik data 41 (Fitur: [-0.38171594 -0.26805847 -0.51291962 -0.48594159]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.143, Inertia sementara: 101.454
# Titik data 42 (Fitur: [-0.41483184 -0.42777553 -0.51291962 -0.48594159]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.202, Inertia sementara: 101.656
# Titik data 43 (Fitur: [-0.42145502 -0.30798773 -0.51291962 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.176, Inertia sementara: 101.832
# Titik data 44 (Fitur: [-0.38171594 -0.26805847 -0.48563021 -0.41204037]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.102, Inertia sementara: 101.934
# Titik data 45 (Fitur: [-0.37509276 -0.2281292  -0.4583408  -0.46130785]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.102, Inertia sementara: 102.036
# Titik data 46 (Fitur: [-0.3949623  -0.33460724 -0.50382315 -0.48594159]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.157, Inertia sementara: 102.193
# Titik data 47 (Fitur: [-0.37509276 -0.2281292  -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.136, Inertia sementara: 102.329
# Titik data 48 (Fitur: [-0.40820866 -0.30798773 -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.166, Inertia sementara: 102.495
# Titik data 49 (Fitur: [-0.3618464  -0.24143896 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.138, Inertia sementara: 102.633
# Titik data 50 (Fitur: [-0.38171594 -0.29467798 -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.155, Inertia sementara: 102.788
# Titik data 51 (Fitur: [3.92335106 3.28564613 3.07108955 2.88888086]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 1.483, Inertia sementara: 104.271
# Titik data 52 (Fitur: [3.28752578 3.28564613 3.05289661 3.13521827]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 0.799, Inertia sementara: 105.070
# Titik data 53 (Fitur: [3.32064168 3.27233638 3.08928249 3.13521827]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 0.748, Inertia sementara: 105.819
# Titik data 54 (Fitur: [2.63183096 1.96798038 3.00741426 2.64254346]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 2.393, Inertia sementara: 108.212
# Titik data 55 (Fitur: [3.29414896 2.03452916 3.06199308 3.13521827]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 1.073, Inertia sementara: 109.284
# Titik data 56 (Fitur: [-0.33535368 -0.36122675 -0.22183258 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.038, Inertia sementara: 109.323
# Titik data 57 (Fitur: [-0.2956146  -0.29467798 -0.20363964 -0.16570296]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.025, Inertia sementara: 109.347
# Titik data 58 (Fitur: [-0.38833912 -0.41446577 -0.33099022 -0.3135054 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.079, Inertia sementara: 109.426
# Titik data 59 (Fitur: [-0.27574506 -0.347917   -0.21273611 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.026, Inertia sementara: 109.452
# Titik data 60 (Fitur: [-0.36846958 -0.37453651 -0.2764114  -0.21497044]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.051, Inertia sementara: 109.504
# Titik data 61 (Fitur: [-0.38171594 -0.46770479 -0.31279728 -0.3135054 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.100, Inertia sementara: 109.604
# Titik data 62 (Fitur: [-0.32210732 -0.33460724 -0.24912199 -0.1903367 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.031, Inertia sementara: 109.635
# Titik data 63 (Fitur: [-0.31548414 -0.44108528 -0.26731493 -0.3135054 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.069, Inertia sementara: 109.703
# Titik data 64 (Fitur: [-0.30886096 -0.347917   -0.20363964 -0.21497044]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.033, Inertia sementara: 109.736
# Titik data 65 (Fitur: [-0.34197686 -0.347917   -0.30370081 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.036, Inertia sementara: 109.773
# Titik data 66 (Fitur: [-0.26912188 -0.32129749 -0.23092905 -0.21497044]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.019, Inertia sementara: 109.792
# Titik data 67 (Fitur: [-0.34197686 -0.33460724 -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.036, Inertia sementara: 109.828
# Titik data 68 (Fitur: [-0.3287305  -0.37453651 -0.25821846 -0.3135054 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.043, Inertia sementara: 109.870
# Titik data 69 (Fitur: [-0.30223778 -0.44108528 -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.070, Inertia sementara: 109.940
# Titik data 70 (Fitur: [-0.34197686 -0.40115602 -0.2764114  -0.28887166]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.054, Inertia sementara: 109.994
# Titik data 71 (Fitur: [-0.32210732 -0.30798773 -0.19454317 -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.044, Inertia sementara: 110.038
# Titik data 72 (Fitur: [-0.30886096 -0.36122675 -0.26731493 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.033, Inertia sementara: 110.070
# Titik data 73 (Fitur: [-0.2956146  -0.40115602 -0.1854467  -0.1903367 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.055, Inertia sementara: 110.125
# Titik data 74 (Fitur: [-0.30886096 -0.36122675 -0.20363964 -0.26423792]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.035, Inertia sementara: 110.160
# Titik data 75 (Fitur: [-0.28899142 -0.347917   -0.24002552 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.026, Inertia sementara: 110.186
# Titik data 76 (Fitur: [-0.27574506 -0.33460724 -0.23092905 -0.21497044]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.023, Inertia sementara: 110.209
# Titik data 77 (Fitur: [-0.2624987  -0.36122675 -0.19454317 -0.21497044]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.033, Inertia sementara: 110.242
# Titik data 78 (Fitur: [-0.26912188 -0.33460724 -0.17635023 -0.14106922]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.040, Inertia sementara: 110.282
# Titik data 79 (Fitur: [-0.31548414 -0.347917   -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.035, Inertia sementara: 110.317
# Titik data 80 (Fitur: [-0.33535368 -0.38784626 -0.31279728 -0.3135054 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.052, Inertia sementara: 110.369
# Titik data 81 (Fitur: [-0.34860004 -0.41446577 -0.28550787 -0.28887166]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.061, Inertia sementara: 110.431
# Titik data 82 (Fitur: [-0.34860004 -0.41446577 -0.29460434 -0.3135054 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.064, Inertia sementara: 110.495
# Titik data 83 (Fitur: [-0.3287305  -0.37453651 -0.2764114  -0.26423792]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.040, Inertia sementara: 110.535
# Titik data 84 (Fitur: [-0.31548414 -0.37453651 -0.16725376 -0.16570296]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.054, Inertia sementara: 110.590
# Titik data 85 (Fitur: [-0.35522322 -0.33460724 -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.039, Inertia sementara: 110.629
# Titik data 86 (Fitur: [-0.31548414 -0.28136822 -0.22183258 -0.16570296]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.023, Inertia sementara: 110.652
# Titik data 87 (Fitur: [-0.26912188 -0.32129749 -0.20363964 -0.1903367 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.024, Inertia sementara: 110.676
# Titik data 88 (Fitur: [-0.2956146  -0.42777553 -0.23092905 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.057, Inertia sementara: 110.733
# Titik data 89 (Fitur: [-0.34197686 -0.33460724 -0.25821846 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.030, Inertia sementara: 110.764
# Titik data 90 (Fitur: [-0.34860004 -0.40115602 -0.26731493 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.055, Inertia sementara: 110.819
# Titik data 91 (Fitur: [-0.34860004 -0.38784626 -0.23092905 -0.26423792]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.050, Inertia sementara: 110.868
# Titik data 92 (Fitur: [-0.30886096 -0.33460724 -0.21273611 -0.21497044]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.028, Inertia sementara: 110.896
# Titik data 93 (Fitur: [-0.3287305  -0.38784626 -0.26731493 -0.26423792]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.045, Inertia sementara: 110.941
# Titik data 94 (Fitur: [-0.38171594 -0.42777553 -0.33099022 -0.3135054 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.083, Inertia sementara: 111.024
# Titik data 95 (Fitur: [-0.34197686 -0.37453651 -0.24912199 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.043, Inertia sementara: 111.067
# Titik data 96 (Fitur: [-0.33535368 -0.33460724 -0.24912199 -0.26423792]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.029, Inertia sementara: 111.096
# Titik data 97 (Fitur: [-0.33535368 -0.347917   -0.24912199 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.033, Inertia sementara: 111.129
# Titik data 98 (Fitur: [-0.30223778 -0.347917   -0.24002552 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.028, Inertia sementara: 111.156
# Titik data 99 (Fitur: [-0.37509276 -0.40115602 -0.35827963 -0.28887166]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.072, Inertia sementara: 111.228
# Titik data 100 (Fitur: [-0.33535368 -0.36122675 -0.25821846 -0.23960418]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.037, Inertia sementara: 111.265
# Titik data 101 (Fitur: [3.2809026  3.29895589 4.82670826 4.490074  ]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 2.534, Inertia sementara: 113.799
# Titik data 102 (Fitur: [2.6517005  2.0212194  3.92615773 4.12056789]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 1.327, Inertia sementara: 115.126
# Titik data 103 (Fitur: [3.92997424 3.25902662 3.99892949 4.39153903]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 1.396, Inertia sementara: 116.522
# Titik data 104 (Fitur: [3.2809026  2.04783891 3.97164008 3.87423048]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 0.728, Inertia sementara: 117.250
# Titik data 105 (Fitur: [3.29414896 3.25902662 3.98983302 4.41617277]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 1.017, Inertia sementara: 118.268
# Titik data 106 (Fitur: [-0.20951326 -0.33460724 -0.03080671 -0.04253426]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.117, Inertia sementara: 118.385
# Titik data 107 (Fitur: [-0.38833912 -0.40115602 -0.22183258 -0.14106922]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.080, Inertia sementara: 118.465
# Titik data 108 (Fitur: [-0.2293828  -0.347917   -0.05809612 -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.082, Inertia sementara: 118.547
# Titik data 109 (Fitur: [-0.26912188 -0.40115602 -0.10357847 -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.086, Inertia sementara: 118.633
# Titik data 110 (Fitur: [-0.23600598 -0.25474871 -0.07628906  0.0560007 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.135, Inertia sementara: 118.768
# Titik data 111 (Fitur: [-0.28236824 -0.30798773 -0.16725376 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.059, Inertia sementara: 118.828
# Titik data 112 (Fitur: [-0.28899142 -0.37453651 -0.14906082 -0.09180174]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.074, Inertia sementara: 118.901
# Titik data 113 (Fitur: [-0.2624987  -0.33460724 -0.13086788 -0.04253426]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.082, Inertia sementara: 118.983
# Titik data 114 (Fitur: [-0.33535368 -0.40115602 -0.17635023 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.095, Inertia sementara: 119.078
# Titik data 115 (Fitur: [-0.3287305  -0.36122675 -0.16725376  0.03136696]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.128, Inertia sementara: 119.205
# Titik data 116 (Fitur: [-0.28899142 -0.30798773 -0.14906082  0.00673322]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.097, Inertia sementara: 119.303
# Titik data 117 (Fitur: [-0.28236824 -0.33460724 -0.13086788 -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.057, Inertia sementara: 119.360
# Titik data 118 (Fitur: [-0.20289008 -0.2281292  -0.02171024 -0.01790052]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.115, Inertia sementara: 119.475
# Titik data 119 (Fitur: [-0.20289008 -0.38784626 -0.0035173   0.00673322]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.172, Inertia sementara: 119.647
# Titik data 120 (Fitur: [-0.31548414 -0.44108528 -0.17635023 -0.1903367 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.077, Inertia sementara: 119.724
# Titik data 121 (Fitur: [-0.25587552 -0.30798773 -0.11267494  0.00673322]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.104, Inertia sementara: 119.828
# Titik data 122 (Fitur: [-0.34197686 -0.36122675 -0.1854467  -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.080, Inertia sementara: 119.907
# Titik data 123 (Fitur: [-0.20289008 -0.36122675 -0.02171024 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.120, Inertia sementara: 120.027
# Titik data 124 (Fitur: [-0.2956146  -0.37453651 -0.1854467  -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.060, Inertia sementara: 120.087
# Titik data 125 (Fitur: [-0.26912188 -0.29467798 -0.11267494 -0.04253426]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.078, Inertia sementara: 120.166
# Titik data 126 (Fitur: [-0.23600598 -0.30798773 -0.08538553 -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.062, Inertia sementara: 120.227
# Titik data 127 (Fitur: [-0.30223778 -0.36122675 -0.19454317 -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.055, Inertia sementara: 120.283
# Titik data 128 (Fitur: [-0.30886096 -0.33460724 -0.1854467  -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.049, Inertia sementara: 120.332
# Titik data 129 (Fitur: [-0.28899142 -0.36122675 -0.12177141 -0.04253426]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.095, Inertia sementara: 120.427
# Titik data 130 (Fitur: [-0.23600598 -0.33460724 -0.10357847 -0.16570296]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.051, Inertia sementara: 120.478
# Titik data 131 (Fitur: [-0.22275962 -0.36122675 -0.07628906 -0.09180174]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.087, Inertia sementara: 120.565
# Titik data 132 (Fitur: [-0.18964372 -0.2281292  -0.04899965 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.083, Inertia sementara: 120.648
# Titik data 133 (Fitur: [-0.28899142 -0.36122675 -0.12177141 -0.01790052]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.106, Inertia sementara: 120.754
# Titik data 134 (Fitur: [-0.2956146  -0.36122675 -0.16725376 -0.1903367 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.043, Inertia sementara: 120.797
# Titik data 135 (Fitur: [-0.30886096 -0.38784626 -0.12177141 -0.21497044]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.062, Inertia sementara: 120.859
# Titik data 136 (Fitur: [-0.20289008 -0.33460724 -0.07628906  0.00673322]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.123, Inertia sementara: 120.982
# Titik data 137 (Fitur: [-0.2956146  -0.28136822 -0.12177141  0.03136696]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.113, Inertia sementara: 121.095
# Titik data 138 (Fitur: [-0.28899142 -0.32129749 -0.13086788 -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.054, Inertia sementara: 121.149
# Titik data 139 (Fitur: [-0.31548414 -0.33460724 -0.19454317 -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.049, Inertia sementara: 121.198
# Titik data 140 (Fitur: [-0.25587552 -0.32129749 -0.13996435 -0.04253426]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.076, Inertia sementara: 121.274
# Titik data 141 (Fitur: [-0.26912188 -0.32129749 -0.12177141  0.03136696]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.119, Inertia sementara: 121.393
# Titik data 142 (Fitur: [-0.25587552 -0.32129749 -0.16725376  0.00673322]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.094, Inertia sementara: 121.487
# Titik data 143 (Fitur: [-0.3287305  -0.37453651 -0.16725376 -0.09180174]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.076, Inertia sementara: 121.563
# Titik data 144 (Fitur: [-0.2624987  -0.30798773 -0.094482    0.00673322]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.110, Inertia sementara: 121.673
# Titik data 145 (Fitur: [-0.26912188 -0.29467798 -0.11267494  0.0560007 ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.130, Inertia sementara: 121.804
# Titik data 146 (Fitur: [-0.26912188 -0.33460724 -0.15815729  0.00673322]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.100, Inertia sementara: 121.904
# Titik data 147 (Fitur: [-0.2956146  -0.40115602 -0.17635023 -0.09180174]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.079, Inertia sementara: 121.983
# Titik data 148 (Fitur: [-0.28236824 -0.33460724 -0.15815729 -0.067168  ]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.067, Inertia sementara: 122.050
# Titik data 149 (Fitur: [-0.30223778 -0.28136822 -0.13996435  0.00673322]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.096, Inertia sementara: 122.146
# Titik data 150 (Fitur: [-0.32210732 -0.33460724 -0.16725376 -0.11643548]), Klaster: 0, Centroid: [-0.2349652  -0.19808718 -0.25711389 -0.25878331], Jarak kuadrat: 0.055, Inertia sementara: 122.201
#
# Total Inertia Manual: 122.201
# Inertia dari sklearn: 122.201
# ==================================================
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[-0.32632653 -0.32750871 -0.2904267  -0.26588017]
#  [ 3.28951274  2.77322056  3.59959446  3.62296633]
#  [ 2.23179089  3.29629394  0.64233207 -0.067168  ]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [ 2.60533824  3.3255754   0.64233207 -0.067168  ]), Klaster: 2, Centroid: [ 2.23179089  3.29629394  0.64233207 -0.067168  ], Jarak kuadrat: 0.140, Inertia sementara: 0.140
# Titik data 2 (Fitur: [ 1.99600568  3.25902662  0.64233207 -0.067168  ]), Klaster: 2, Centroid: [ 2.23179089  3.29629394  0.64233207 -0.067168  ], Jarak kuadrat: 0.057, Inertia sementara: 0.197
# Titik data 3 (Fitur: [ 1.98275932  3.28564613  0.55136737 -0.067168  ]), Klaster: 2, Centroid: [ 2.23179089  3.29629394  0.64233207 -0.067168  ], Jarak kuadrat: 0.070, Inertia sementara: 0.268
# Titik data 4 (Fitur: [ 1.97613614  3.27233638  0.73329677 -0.067168  ]), Klaster: 2, Centroid: [ 2.23179089  3.29629394  0.64233207 -0.067168  ], Jarak kuadrat: 0.074, Inertia sementara: 0.342
# Titik data 5 (Fitur: [ 2.59871506  3.33888515  0.64233207 -0.067168  ]), Klaster: 2, Centroid: [ 2.23179089  3.29629394  0.64233207 -0.067168  ], Jarak kuadrat: 0.136, Inertia sementara: 0.478
# Titik data 6 (Fitur: [-0.35522322 -0.21481945 -0.47653374 -0.46130785]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.086, Inertia sementara: 0.565
# Titik data 7 (Fitur: [-0.40820866 -0.28136822 -0.50382315 -0.48594159]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.103, Inertia sementara: 0.668
# Titik data 8 (Fitur: [-0.38171594 -0.28136822 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.107, Inertia sementara: 0.774
# Titik data 9 (Fitur: [-0.42145502 -0.347917   -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.115, Inertia sementara: 0.889
# Titik data 10 (Fitur: [-0.38833912 -0.32129749 -0.49472668 -0.53520907]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.118, Inertia sementara: 1.007
# Titik data 11 (Fitur: [-0.35522322 -0.24143896 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.110, Inertia sementara: 1.117
# Titik data 12 (Fitur: [-0.3949623  -0.28136822 -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.105, Inertia sementara: 1.222
# Titik data 13 (Fitur: [-0.3949623  -0.33460724 -0.50382315 -0.53520907]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.123, Inertia sementara: 1.345
# Titik data 14 (Fitur: [-0.4280782  -0.33460724 -0.53111256 -0.53520907]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.141, Inertia sementara: 1.486
# Titik data 15 (Fitur: [-0.3287305  -0.20150969 -0.52201609 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.129, Inertia sementara: 1.615
# Titik data 16 (Fitur: [-0.33535368 -0.14827067 -0.49472668 -0.46130785]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.112, Inertia sementara: 1.727
# Titik data 17 (Fitur: [-0.35522322 -0.21481945 -0.51291962 -0.46130785]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.101, Inertia sementara: 1.829
# Titik data 18 (Fitur: [-0.37509276 -0.26805847 -0.50382315 -0.48594159]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.100, Inertia sementara: 1.928
# Titik data 19 (Fitur: [-0.33535368 -0.2281292  -0.47653374 -0.48594159]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.093, Inertia sementara: 2.021
# Titik data 20 (Fitur: [-0.37509276 -0.2281292  -0.49472668 -0.48594159]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.102, Inertia sementara: 2.124
# Titik data 21 (Fitur: [-0.35522322 -0.28136822 -0.47653374 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.097, Inertia sementara: 2.221
# Titik data 22 (Fitur: [-0.37509276 -0.24143896 -0.49472668 -0.46130785]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.090, Inertia sementara: 2.311
# Titik data 23 (Fitur: [-0.40820866 -0.25474871 -0.54020903 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.134, Inertia sementara: 2.445
# Titik data 24 (Fitur: [-0.37509276 -0.29467798 -0.47653374 -0.43667411]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.067, Inertia sementara: 2.513
# Titik data 25 (Fitur: [-0.3949623  -0.28136822 -0.4583408  -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.095, Inertia sementara: 2.608
# Titik data 26 (Fitur: [-0.38171594 -0.33460724 -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.101, Inertia sementara: 2.709
# Titik data 27 (Fitur: [-0.38171594 -0.28136822 -0.48563021 -0.46130785]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.081, Inertia sementara: 2.790
# Titik data 28 (Fitur: [-0.36846958 -0.26805847 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.107, Inertia sementara: 2.897
# Titik data 29 (Fitur: [-0.36846958 -0.28136822 -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.109, Inertia sementara: 3.006
# Titik data 30 (Fitur: [-0.40158548 -0.30798773 -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.104, Inertia sementara: 3.110
# Titik data 31 (Fitur: [-0.3949623  -0.32129749 -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.103, Inertia sementara: 3.213
# Titik data 32 (Fitur: [-0.35522322 -0.28136822 -0.49472668 -0.46130785]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.083, Inertia sementara: 3.296
# Titik data 33 (Fitur: [-0.36846958 -0.18819994 -0.49472668 -0.53520907]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.135, Inertia sementara: 3.431
# Titik data 34 (Fitur: [-0.34860004 -0.17489018 -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.129, Inertia sementara: 3.561
# Titik data 35 (Fitur: [-0.38833912 -0.32129749 -0.49472668 -0.53520907]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.118, Inertia sementara: 3.679
# Titik data 36 (Fitur: [-0.38171594 -0.30798773 -0.52201609 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.117, Inertia sementara: 3.796
# Titik data 37 (Fitur: [-0.34860004 -0.26805847 -0.51291962 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.113, Inertia sementara: 3.909
# Titik data 38 (Fitur: [-0.38833912 -0.32129749 -0.49472668 -0.53520907]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.118, Inertia sementara: 4.027
# Titik data 39 (Fitur: [-0.42145502 -0.33460724 -0.51291962 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.118, Inertia sementara: 4.146
# Titik data 40 (Fitur: [-0.37509276 -0.28136822 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.106, Inertia sementara: 4.252
# Titik data 41 (Fitur: [-0.38171594 -0.26805847 -0.51291962 -0.48594159]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.105, Inertia sementara: 4.357
# Titik data 42 (Fitur: [-0.41483184 -0.42777553 -0.51291962 -0.48594159]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.116, Inertia sementara: 4.472
# Titik data 43 (Fitur: [-0.42145502 -0.30798773 -0.51291962 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.119, Inertia sementara: 4.591
# Titik data 44 (Fitur: [-0.38171594 -0.26805847 -0.48563021 -0.41204037]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.066, Inertia sementara: 4.657
# Titik data 45 (Fitur: [-0.37509276 -0.2281292  -0.4583408  -0.46130785]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.079, Inertia sementara: 4.736
# Titik data 46 (Fitur: [-0.3949623  -0.33460724 -0.50382315 -0.48594159]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.099, Inertia sementara: 4.835
# Titik data 47 (Fitur: [-0.37509276 -0.2281292  -0.48563021 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.110, Inertia sementara: 4.945
# Titik data 48 (Fitur: [-0.40820866 -0.30798773 -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.112, Inertia sementara: 5.057
# Titik data 49 (Fitur: [-0.3618464  -0.24143896 -0.49472668 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.110, Inertia sementara: 5.168
# Titik data 50 (Fitur: [-0.38171594 -0.29467798 -0.50382315 -0.51057533]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.110, Inertia sementara: 5.277
# Titik data 51 (Fitur: [3.92335106 3.28564613 3.07108955 2.88888086]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 1.483, Inertia sementara: 6.760
# Titik data 52 (Fitur: [3.28752578 3.28564613 3.05289661 3.13521827]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 0.799, Inertia sementara: 7.559
# Titik data 53 (Fitur: [3.32064168 3.27233638 3.08928249 3.13521827]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 0.748, Inertia sementara: 8.307
# Titik data 54 (Fitur: [2.63183096 1.96798038 3.00741426 2.64254346]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 2.393, Inertia sementara: 10.700
# Titik data 55 (Fitur: [3.29414896 2.03452916 3.06199308 3.13521827]), Klaster: 1, Centroid: [3.28951274 2.77322056 3.59959446 3.62296633], Jarak kuadrat: 1.073, Inertia sementara: 11.773
# Titik data 56 (Fitur: [-0.33535368 -0.36122675 -0.22183258 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.007, Inertia sementara: 11.780
# Titik data 57 (Fitur: [-0.2956146  -0.29467798 -0.20363964 -0.16570296]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.020, Inertia sementara: 11.799
# Titik data 58 (Fitur: [-0.38833912 -0.41446577 -0.33099022 -0.3135054 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.015, Inertia sementara: 11.814
# Titik data 59 (Fitur: [-0.27574506 -0.347917   -0.21273611 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.010, Inertia sementara: 11.824
# Titik data 60 (Fitur: [-0.36846958 -0.37453651 -0.2764114  -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.007, Inertia sementara: 11.831
# Titik data 61 (Fitur: [-0.38171594 -0.46770479 -0.31279728 -0.3135054 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.025, Inertia sementara: 11.856
# Titik data 62 (Fitur: [-0.32210732 -0.33460724 -0.24912199 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.007, Inertia sementara: 11.864
# Titik data 63 (Fitur: [-0.31548414 -0.44108528 -0.26731493 -0.3135054 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.016, Inertia sementara: 11.880
# Titik data 64 (Fitur: [-0.30886096 -0.347917   -0.20363964 -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.011, Inertia sementara: 11.891
# Titik data 65 (Fitur: [-0.34197686 -0.347917   -0.30370081 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.002, Inertia sementara: 11.892
# Titik data 66 (Fitur: [-0.26912188 -0.32129749 -0.23092905 -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.009, Inertia sementara: 11.902
# Titik data 67 (Fitur: [-0.34197686 -0.33460724 -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.011, Inertia sementara: 11.912
# Titik data 68 (Fitur: [-0.3287305  -0.37453651 -0.25821846 -0.3135054 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.006, Inertia sementara: 11.918
# Titik data 69 (Fitur: [-0.30223778 -0.44108528 -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.024, Inertia sementara: 11.942
# Titik data 70 (Fitur: [-0.34197686 -0.40115602 -0.2764114  -0.28887166]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.006, Inertia sementara: 11.948
# Titik data 71 (Fitur: [-0.32210732 -0.30798773 -0.19454317 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.032, Inertia sementara: 11.980
# Titik data 72 (Fitur: [-0.30886096 -0.36122675 -0.26731493 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.003, Inertia sementara: 11.983
# Titik data 73 (Fitur: [-0.2956146  -0.40115602 -0.1854467  -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.023, Inertia sementara: 12.006
# Titik data 74 (Fitur: [-0.30886096 -0.36122675 -0.20363964 -0.26423792]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.009, Inertia sementara: 12.015
# Titik data 75 (Fitur: [-0.28899142 -0.347917   -0.24002552 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.005, Inertia sementara: 12.020
# Titik data 76 (Fitur: [-0.27574506 -0.33460724 -0.23092905 -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.009, Inertia sementara: 12.028
# Titik data 77 (Fitur: [-0.2624987  -0.36122675 -0.19454317 -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.017, Inertia sementara: 12.045
# Titik data 78 (Fitur: [-0.26912188 -0.33460724 -0.17635023 -0.14106922]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.032, Inertia sementara: 12.077
# Titik data 79 (Fitur: [-0.31548414 -0.347917   -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.011, Inertia sementara: 12.088
# Titik data 80 (Fitur: [-0.33535368 -0.38784626 -0.31279728 -0.3135054 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.006, Inertia sementara: 12.095
# Titik data 81 (Fitur: [-0.34860004 -0.41446577 -0.28550787 -0.28887166]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.009, Inertia sementara: 12.103
# Titik data 82 (Fitur: [-0.34860004 -0.41446577 -0.29460434 -0.3135054 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.010, Inertia sementara: 12.114
# Titik data 83 (Fitur: [-0.3287305  -0.37453651 -0.2764114  -0.26423792]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.002, Inertia sementara: 12.116
# Titik data 84 (Fitur: [-0.31548414 -0.37453651 -0.16725376 -0.16570296]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.028, Inertia sementara: 12.144
# Titik data 85 (Fitur: [-0.35522322 -0.33460724 -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.011, Inertia sementara: 12.155
# Titik data 86 (Fitur: [-0.31548414 -0.28136822 -0.22183258 -0.16570296]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.017, Inertia sementara: 12.172
# Titik data 87 (Fitur: [-0.26912188 -0.32129749 -0.20363964 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.017, Inertia sementara: 12.189
# Titik data 88 (Fitur: [-0.2956146  -0.42777553 -0.23092905 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.015, Inertia sementara: 12.204
# Titik data 89 (Fitur: [-0.34197686 -0.33460724 -0.25821846 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.002, Inertia sementara: 12.206
# Titik data 90 (Fitur: [-0.34860004 -0.40115602 -0.26731493 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.007, Inertia sementara: 12.213
# Titik data 91 (Fitur: [-0.34860004 -0.38784626 -0.23092905 -0.26423792]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.008, Inertia sementara: 12.221
# Titik data 92 (Fitur: [-0.30886096 -0.33460724 -0.21273611 -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.009, Inertia sementara: 12.230
# Titik data 93 (Fitur: [-0.3287305  -0.38784626 -0.26731493 -0.26423792]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.004, Inertia sementara: 12.234
# ...
# Titik data 70 (Fitur: [-0.34197686 -0.40115602 -0.2764114  -0.28887166]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.006, Inertia sementara: 8.454
# Titik data 71 (Fitur: [-0.32210732 -0.30798773 -0.19454317 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.032, Inertia sementara: 8.486
# Titik data 72 (Fitur: [-0.30886096 -0.36122675 -0.26731493 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.003, Inertia sementara: 8.488
# Titik data 73 (Fitur: [-0.2956146  -0.40115602 -0.1854467  -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.023, Inertia sementara: 8.511
# Titik data 74 (Fitur: [-0.30886096 -0.36122675 -0.20363964 -0.26423792]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.009, Inertia sementara: 8.520
# Titik data 75 (Fitur: [-0.28899142 -0.347917   -0.24002552 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.005, Inertia sementara: 8.525
# Titik data 76 (Fitur: [-0.27574506 -0.33460724 -0.23092905 -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.009, Inertia sementara: 8.534
# Titik data 77 (Fitur: [-0.2624987  -0.36122675 -0.19454317 -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.017, Inertia sementara: 8.551
# Titik data 78 (Fitur: [-0.26912188 -0.33460724 -0.17635023 -0.14106922]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.032, Inertia sementara: 8.583
# Titik data 79 (Fitur: [-0.31548414 -0.347917   -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.011, Inertia sementara: 8.594
# Titik data 80 (Fitur: [-0.33535368 -0.38784626 -0.31279728 -0.3135054 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.006, Inertia sementara: 8.601
# Titik data 81 (Fitur: [-0.34860004 -0.41446577 -0.28550787 -0.28887166]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.009, Inertia sementara: 8.609
# Titik data 82 (Fitur: [-0.34860004 -0.41446577 -0.29460434 -0.3135054 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.010, Inertia sementara: 8.619
# Titik data 83 (Fitur: [-0.3287305  -0.37453651 -0.2764114  -0.26423792]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.002, Inertia sementara: 8.622
# Titik data 84 (Fitur: [-0.31548414 -0.37453651 -0.16725376 -0.16570296]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.028, Inertia sementara: 8.649
# Titik data 85 (Fitur: [-0.35522322 -0.33460724 -0.22183258 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.011, Inertia sementara: 8.661
# Titik data 86 (Fitur: [-0.31548414 -0.28136822 -0.22183258 -0.16570296]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.017, Inertia sementara: 8.678
# Titik data 87 (Fitur: [-0.26912188 -0.32129749 -0.20363964 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.017, Inertia sementara: 8.694
# Titik data 88 (Fitur: [-0.2956146  -0.42777553 -0.23092905 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.015, Inertia sementara: 8.710
# Titik data 89 (Fitur: [-0.34197686 -0.33460724 -0.25821846 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.002, Inertia sementara: 8.712
# Titik data 90 (Fitur: [-0.34860004 -0.40115602 -0.26731493 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.007, Inertia sementara: 8.719
# Titik data 91 (Fitur: [-0.34860004 -0.38784626 -0.23092905 -0.26423792]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.008, Inertia sementara: 8.726
# Titik data 92 (Fitur: [-0.30886096 -0.33460724 -0.21273611 -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.009, Inertia sementara: 8.735
# Titik data 93 (Fitur: [-0.3287305  -0.38784626 -0.26731493 -0.26423792]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.004, Inertia sementara: 8.740
# Titik data 94 (Fitur: [-0.38171594 -0.42777553 -0.33099022 -0.3135054 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.017, Inertia sementara: 8.757
# Titik data 95 (Fitur: [-0.34197686 -0.37453651 -0.24912199 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.005, Inertia sementara: 8.761
# Titik data 96 (Fitur: [-0.33535368 -0.33460724 -0.24912199 -0.26423792]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.002, Inertia sementara: 8.763
# Titik data 97 (Fitur: [-0.33535368 -0.347917   -0.24912199 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.003, Inertia sementara: 8.766
# Titik data 98 (Fitur: [-0.30223778 -0.347917   -0.24002552 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.004, Inertia sementara: 8.770
# Titik data 99 (Fitur: [-0.37509276 -0.40115602 -0.35827963 -0.28887166]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.013, Inertia sementara: 8.783
# Titik data 100 (Fitur: [-0.33535368 -0.36122675 -0.25821846 -0.23960418]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.003, Inertia sementara: 8.786
# Titik data 101 (Fitur: [3.2809026  3.29895589 4.82670826 4.490074  ]), Klaster: 1, Centroid: [3.28752578 2.77721349 4.14265371 4.25851683], Jarak kuadrat: 0.794, Inertia sementara: 9.580
# Titik data 102 (Fitur: [2.6517005  2.0212194  3.92615773 4.12056789]), Klaster: 1, Centroid: [3.28752578 2.77721349 4.14265371 4.25851683], Jarak kuadrat: 1.042, Inertia sementara: 10.622
# Titik data 103 (Fitur: [3.92997424 3.25902662 3.99892949 4.39153903]), Klaster: 1, Centroid: [3.28752578 2.77721349 4.14265371 4.25851683], Jarak kuadrat: 0.683, Inertia sementara: 11.305
# Titik data 104 (Fitur: [3.2809026  2.04783891 3.97164008 3.87423048]), Klaster: 1, Centroid: [3.28752578 2.77721349 4.14265371 4.25851683], Jarak kuadrat: 0.709, Inertia sementara: 12.014
# Titik data 105 (Fitur: [3.29414896 3.25902662 3.98983302 4.41617277]), Klaster: 1, Centroid: [3.28752578 2.77721349 4.14265371 4.25851683], Jarak kuadrat: 0.280, Inertia sementara: 12.294
# Titik data 106 (Fitur: [-0.20951326 -0.33460724 -0.03080671 -0.04253426]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.131, Inertia sementara: 12.425
# Titik data 107 (Fitur: [-0.38833912 -0.40115602 -0.22183258 -0.14106922]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.030, Inertia sementara: 12.455
# Titik data 108 (Fitur: [-0.2293828  -0.347917   -0.05809612 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.086, Inertia sementara: 12.541
# Titik data 109 (Fitur: [-0.26912188 -0.40115602 -0.10357847 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.066, Inertia sementara: 12.607
# Titik data 110 (Fitur: [-0.23600598 -0.25474871 -0.07628906  0.0560007 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.163, Inertia sementara: 12.770
# Titik data 111 (Fitur: [-0.28236824 -0.30798773 -0.16725376 -0.067168  ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.057, Inertia sementara: 12.827
# Titik data 112 (Fitur: [-0.28899142 -0.37453651 -0.14906082 -0.09180174]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.054, Inertia sementara: 12.881
# Titik data 113 (Fitur: [-0.2624987  -0.33460724 -0.13086788 -0.04253426]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.079, Inertia sementara: 12.960
# Titik data 114 (Fitur: [-0.33535368 -0.40115602 -0.17635023 -0.067168  ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.058, Inertia sementara: 13.018
# Titik data 115 (Fitur: [-0.3287305  -0.36122675 -0.16725376  0.03136696]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.105, Inertia sementara: 13.123
# Titik data 116 (Fitur: [-0.28899142 -0.30798773 -0.14906082  0.00673322]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.096, Inertia sementara: 13.219
# Titik data 117 (Fitur: [-0.28236824 -0.33460724 -0.13086788 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.050, Inertia sementara: 13.269
# Titik data 118 (Fitur: [-0.20289008 -0.2281292  -0.02171024 -0.01790052]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.159, Inertia sementara: 13.428
# Titik data 119 (Fitur: [-0.20289008 -0.38784626 -0.0035173   0.00673322]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.176, Inertia sementara: 13.603
# Titik data 120 (Fitur: [-0.31548414 -0.44108528 -0.17635023 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.032, Inertia sementara: 13.635
# Titik data 121 (Fitur: [-0.25587552 -0.30798773 -0.11267494  0.00673322]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.111, Inertia sementara: 13.746
# Titik data 122 (Fitur: [-0.34197686 -0.36122675 -0.1854467  -0.067168  ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.052, Inertia sementara: 13.798
# Titik data 123 (Fitur: [-0.20289008 -0.36122675 -0.02171024 -0.067168  ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.128, Inertia sementara: 13.926
# Titik data 124 (Fitur: [-0.2956146  -0.37453651 -0.1854467  -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.037, Inertia sementara: 13.963
# Titik data 125 (Fitur: [-0.26912188 -0.29467798 -0.11267494 -0.04253426]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.086, Inertia sementara: 14.048
# Titik data 126 (Fitur: [-0.23600598 -0.30798773 -0.08538553 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.073, Inertia sementara: 14.121
# Titik data 127 (Fitur: [-0.30223778 -0.36122675 -0.19454317 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.033, Inertia sementara: 14.154
# Titik data 128 (Fitur: [-0.30886096 -0.33460724 -0.1854467  -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.034, Inertia sementara: 14.188
# Titik data 129 (Fitur: [-0.28899142 -0.36122675 -0.12177141 -0.04253426]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.081, Inertia sementara: 14.269
# Titik data 130 (Fitur: [-0.23600598 -0.33460724 -0.10357847 -0.16570296]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.053, Inertia sementara: 14.322
# Titik data 131 (Fitur: [-0.22275962 -0.36122675 -0.07628906 -0.09180174]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.088, Inertia sementara: 14.410
# Titik data 132 (Fitur: [-0.18964372 -0.2281292  -0.04899965 -0.067168  ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.126, Inertia sementara: 14.537
# Titik data 133 (Fitur: [-0.28899142 -0.36122675 -0.12177141 -0.01790052]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.092, Inertia sementara: 14.629
# Titik data 134 (Fitur: [-0.2956146  -0.36122675 -0.16725376 -0.1903367 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.023, Inertia sementara: 14.652
# Titik data 135 (Fitur: [-0.30886096 -0.38784626 -0.12177141 -0.21497044]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.035, Inertia sementara: 14.687
# Titik data 136 (Fitur: [-0.20289008 -0.33460724 -0.07628906  0.00673322]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.135, Inertia sementara: 14.822
# Titik data 137 (Fitur: [-0.2956146  -0.28136822 -0.12177141  0.03136696]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.120, Inertia sementara: 14.942
# Titik data 138 (Fitur: [-0.28899142 -0.32129749 -0.13086788 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.049, Inertia sementara: 14.992
# Titik data 139 (Fitur: [-0.31548414 -0.33460724 -0.19454317 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.032, Inertia sementara: 15.023
# Titik data 140 (Fitur: [-0.25587552 -0.32129749 -0.13996435 -0.04253426]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.078, Inertia sementara: 15.101
# Titik data 141 (Fitur: [-0.26912188 -0.32129749 -0.12177141  0.03136696]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.120, Inertia sementara: 15.221
# Titik data 142 (Fitur: [-0.25587552 -0.32129749 -0.16725376  0.00673322]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.094, Inertia sementara: 15.315
# Titik data 143 (Fitur: [-0.3287305  -0.37453651 -0.16725376 -0.09180174]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.048, Inertia sementara: 15.363
# Titik data 144 (Fitur: [-0.2624987  -0.30798773 -0.094482    0.00673322]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.117, Inertia sementara: 15.480
# Titik data 145 (Fitur: [-0.26912188 -0.29467798 -0.11267494  0.0560007 ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.140, Inertia sementara: 15.620
# Titik data 146 (Fitur: [-0.26912188 -0.33460724 -0.15815729  0.00673322]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.095, Inertia sementara: 15.715
# Titik data 147 (Fitur: [-0.2956146  -0.40115602 -0.17635023 -0.09180174]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.050, Inertia sementara: 15.765
# Titik data 148 (Fitur: [-0.28236824 -0.33460724 -0.15815729 -0.067168  ]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.059, Inertia sementara: 15.824
# Titik data 149 (Fitur: [-0.30223778 -0.28136822 -0.13996435  0.00673322]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.100, Inertia sementara: 15.923
# Titik data 150 (Fitur: [-0.32210732 -0.33460724 -0.16725376 -0.11643548]), Klaster: 0, Centroid: [-0.32632653 -0.32750871 -0.2904267  -0.26588017], Jarak kuadrat: 0.038, Inertia sementara: 15.961
#
# Total Inertia Manual: 15.961
# Inertia dari sklearn: 15.961
# ==================================================

# %% [markdown]
# ## **Model Plotting Diagram Elbow Method**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Hitung inertia untuk berbagai nilai k
inertias = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertias.append(kmeans.inertia_)

# 4. Plot Elbow Diagram
plt.figure(figsize=(9, 6))
plt.plot(K_range, inertias, 'bo-', markersize=8, label='Inertia')
plt.title("Metode Elbow - Menentukan Jumlah Klaster Optimal")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Inertia")
plt.xticks(K_range)
plt.grid(True)

# Tambahkan label inertia di tiap titik
for i, inertia in enumerate(inertias):
    plt.text(K_range[i], inertias[i] + 1, f"{inertia:.2f}", ha='center', fontsize=9)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Menghitung Silhouette Score untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk melakukan K-Means dan menghitung Silhouette Score
def perform_kmeans_with_silhouette(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    # Menghitung Silhouette Score
    silhouette_avg = silhouette_score(X_scaled, labels)

    # Centroid dari masing-masing klaster
    centroids = kmeans.cluster_centers_

    # Output hasil untuk klaster k
    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids:\n{centroids}")
    print(f"Silhouette Score untuk {k} klaster: {silhouette_avg:.3f}")

    return silhouette_avg

# 4. Melakukan clustering dan menghitung Silhouette Score untuk k=2, 3, dan 4
silhouette_scores = []
k_values = [2, 3, 4]

for k in k_values:
    score = perform_kmeans_with_silhouette(X_scaled, k)
    silhouette_scores.append(score)

# 5. Menentukan k dengan Silhouette Score terbaik
best_k = k_values[np.argmax(silhouette_scores)]
best_score = max(silhouette_scores)
print(f"\n>>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = {best_k} (dengan score = {best_score:.3f})")

# 6. Plot Silhouette Scores
plt.figure(figsize=(8, 5))
plt.plot(k_values, silhouette_scores, 'bo-', markersize=8)
plt.title("Silhouette Score untuk Jumlah Klaster yang Berbeda")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Silhouette Score")
plt.xticks(k_values)
plt.grid(True)
plt.show()
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids:
# [[-0.2349652  -0.19808718 -0.25711389 -0.25878331]
#  [ 3.28951274  2.77322056  3.59959446  3.62296633]]
# Silhouette Score untuk 2 klaster: 0.898
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids:
# [[-0.32632653 -0.32750871 -0.2904267  -0.26588017]
#  [ 3.28951274  2.77322056  3.59959446  3.62296633]
#  [ 2.23179089  3.29629394  0.64233207 -0.067168  ]]
# Silhouette Score untuk 3 klaster: 0.913
#
# === Hasil K-Means dengan 4 Klaster ===
# Centroids:
# [[-0.32632653 -0.32750871 -0.2904267  -0.26588017]
#  [ 3.28752578  2.77721349  4.14265371  4.25851683]
#  [ 2.23179089  3.29629394  0.64233207 -0.067168  ]
#  [ 3.29149969  2.76922764  3.0565352   2.98741582]]
# Silhouette Score untuk 4 klaster: 0.895
#
# >>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = 3 (dengan score = 0.913)
